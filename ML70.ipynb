# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('hr_data.csv')
df.head(40)
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.38             0.53               2                   157
# 1                 0.80             0.86               5                   262
# 2                 0.11             0.88               7                   272
# 3                 0.72             0.87               5                   223
# 4                 0.37             0.52               2                   159
# 5                 0.41             0.50               2                   153
# 6                 0.10             0.77               6                   247
# 7                 0.92             0.85               5                   259
# 8                 0.89             1.00               5                   224
# 9                 0.42             0.53               2                   142
# 10                0.45             0.54               2                   135
# ...

# %%
plt.scatter(df['satisfaction_level'],df['left'],color='red')

# %%
df_salary = pd.get_dummies(df['salary'])

# %%
df_dummy = pd.concat([df,df_salary],axis=1)

# %%
df_dummy = df_dummy.drop(['salary'],axis=1)
df_dummy.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    high  low  medium
# ...

# %%
real_x = df_dummy.iloc[:,[0,1,2,3,4,5,7,9,10,11]].values
real_x
# Out:
# array([[0.38, 0.53, 2.  , ..., 0.  , 1.  , 0.  ],
#        [0.8 , 0.86, 5.  , ..., 0.  , 0.  , 1.  ],
#        [0.11, 0.88, 7.  , ..., 0.  , 0.  , 1.  ],
#        ...,
#        [0.37, 0.53, 2.  , ..., 0.  , 1.  , 0.  ],
#        [0.11, 0.96, 6.  , ..., 0.  , 1.  , 0.  ],
#        [0.37, 0.52, 2.  , ..., 0.  , 1.  , 0.  ]])

# %%
real_y =df_dummy.iloc[:,6].values
real_y
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
training_x,testing_x,training_y,testing_y = train_test_split(real_x,real_y,test_size=0.3,random_state=0)

# %%
log_reg = LogisticRegression(solver='liblinear')
log_reg.fit(training_x,training_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
log_reg.predict(testing_x)
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
log_reg.score(testing_x,testing_y)
# Out:
# 0.7873333333333333
