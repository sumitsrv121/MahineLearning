# %%
import matplotlib.pyplot as plt

activities = ['eat','sleep','study','entertainment']
slices = [3,7,8,6]
color = ['r','g','m','b']

plt.pie(slices,labels=activities,colors=color,startangle=90,shadow=True,explode=(0,0,0,0.2),autopct='%1.2F%%')
plt.legend()
plt.show()
