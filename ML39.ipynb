# %%
import pandas as pd

df = pd.read_csv('employee.csv')
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 39.1+ KB

# %%
pd.to_datetime(df['Start Date'])
df['Start Date'] = pd.to_datetime(df['Start Date'])
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
pd.to_datetime(df['Last Login Time']).dt.strftime('%H:%M:%S')
df['Last Login Time'] = pd.to_datetime(df['Last Login Time']).dt.strftime('%H:%M:%S')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 37.2+ KB

# %%
pd.read_csv('employee.csv',parse_dates=['Start Date','Last Login Time'])
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2019-08-27 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2019-08-27 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2019-08-27 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2019-08-27 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2019-08-27 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2019-08-27 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2019-08-27 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2019-08-27 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2019-08-27 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2019-08-27 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df['Senior Management'] = df['Senior Management'].astype(bool)

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df['Gender'].astype('category')
df['Gender'] = df['Gender'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 37.2+ KB
